# %%
import cv2
import pandas as pd
from ultralytics import YOLO
from tracker import*

model=YOLO('yolov9c.pt')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[7], line 4
#       2 import pandas as pd
#       3 from ultralytics import YOLO
# ----> 4 from tracker import*
#       6 model=YOLO('yolov9c.pt')
#
# File ~\AppData\Roaming\Python\Python311\site-packages\tracker\__init__.py:1
# ----> 1 from .tracker import tracked
#
# File ~\AppData\Roaming\Python\Python311\site-packages\tracker\tracker.py:4
#       1 from collections import namedtuple
#       2 import inspect
# ----> 4 from .snapshot import Snapshot
#       7 Frame = namedtuple('Frame', ['file', 'line', 'context'])
#       8 Step = namedtuple('Step', ['name', 'value', 'stack'])
#
# File ~\AppData\Roaming\Python\Python311\site-packages\tracker\snapshot.py:2
#       1 import textwrap
# ----> 2 from itertools import izip_longest
#       4 from .tracker import __file__ as SOURCE_FILE
#       6 class Snapshot(object):
#
# ...

# %%
# !pip install ultralytics
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Obtaining dependency information for ultralytics from https://files.pythonhosted.org/packages/1e/83/6068811d27ba97c74870cbfbd66d8a5edb49b30f3ba4f2e8c7e499e0dae6/ultralytics-8.1.25-py3-none-any.whl.metadata
# ...
#      ---------------------------------------- 0.0/40.3 kB ? eta -:--:--
#      -------------------------------------- 40.3/40.3 kB 940.3 kB/s eta 0:00:00
# ...
#   Obtaining dependency information for torch>=1.8.0 from https://files.pythonhosted.org/packages/59/1f/4975d1ab3ed2244053876321ef65bc02935daed67da76c6e7d65900772a3/torch-2.2.1-cp311-cp311-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for torchvision>=0.9.0 from https://files.pythonhosted.org/packages/e7/45/419aa0b37254f1fd62b45bb63836066c5eb81e37d70940e0491e95167eed/torchvision-0.17.1-cp311-cp311-win_amd64.whl.metadata
# ...

# %%
# !pip install tracker
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for tracker: filename=tracker-0.1.1-py3-none-any.whl size=3116 sha256=a1e50e68053975c54752497300ea0a858a715e28db17d1696a567e1c40776447
#   Stored in directory: c:\users\asus\appdata\local\pip\cache\wheels\34\de\1d\192fde02b61fde4d3411efdb4082f788c8bc472794a649f6e4
# Successfully built tracker
# ...
